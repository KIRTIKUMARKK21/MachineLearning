# %%
import pandas as pd

# %%
df=pd.read_csv('data/survey_results_public.csv',index_col='Respondent')
schema_df=pd.read_csv('data/survey_results_schema.csv',index_col='Column')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
schema_df.sort_index()
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
high_salary=(df['ConvertedComp']>70000)

# %%
df2=df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]

# %%
df2.sort_values(by='ConvertedComp',ascending=False,inplace=True)

# %%
df2.head(10)
# Out:
#                   Country                                 LanguageWorkedWith  \
# Respondent
# 32406       United States             C#;HTML/CSS;JavaScript;Python;Ruby;SQL
# 45362       United States                                                NaN
# 45352       United States         Bash/Shell/PowerShell;C#;JavaScript;Python
# 1022        United States      HTML/CSS;Java;JavaScript;Scala;SQL;TypeScript
# 53449       United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 3295        United States  Assembly;Bash/Shell/PowerShell;C;C#;C++;HTML/C...
# 16829       United States                             Julia;Python;R;SQL;VBA
# 3279        United States                         C#;HTML/CSS;JavaScript;SQL
# 29359       United States    Assembly;Bash/Shell/PowerShell;C;C++;Python;SQL
# 60832       United States                                HTML/CSS;JavaScript
#
#             ConvertedComp
# Respondent
# 32406           2000000.0
# 45362           2000000.0
# ...

# %%
countries=['India','United States','United Kingdom']
filt1=df2['Country'].isin(countries)

# %%
df2.loc[filt1]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 32406        United States             C#;HTML/CSS;JavaScript;Python;Ruby;SQL
# 45362        United States                                                NaN
# 45352        United States         Bash/Shell/PowerShell;C#;JavaScript;Python
# 1022         United States      HTML/CSS;Java;JavaScript;Scala;SQL;TypeScript
# 53449        United States  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# ...                    ...                                                ...
# 11338                India               C;C++;HTML/CSS;JavaScript;PHP;Python
# 462          United States              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 60724        United States                     C#;C++;HTML/CSS;JavaScript;SQL
# 13671       United Kingdom  Bash/Shell/PowerShell;C#;Java;JavaScript;SQL;T...
# 58883        United States                      C#;Java;JavaScript;Python;SQL
#
# ...

# %%
filt=df2['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
df2.loc[filt].head(10)
# Out:
#                   Country                                 LanguageWorkedWith  \
# Respondent
# 32406       United States             C#;HTML/CSS;JavaScript;Python;Ruby;SQL
# 45352       United States         Bash/Shell/PowerShell;C#;JavaScript;Python
# 3295        United States  Assembly;Bash/Shell/PowerShell;C;C#;C++;HTML/C...
# 16829       United States                             Julia;Python;R;SQL;VBA
# 29359       United States    Assembly;Bash/Shell/PowerShell;C;C++;Python;SQL
# 3261        United States                    HTML/CSS;Java;JavaScript;Python
# 53523       United States  Bash/Shell/PowerShell;C;HTML/CSS;Java;JavaScri...
# 61117       United States  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 3236        United States                C;C#;C++;HTML/CSS;JavaScript;Python
# 44313       United States                                    HTML/CSS;Python
#
#             ConvertedComp
# Respondent
# 32406           2000000.0
# 45352           2000000.0
# ...
