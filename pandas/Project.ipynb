# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('weather.csv')

# %%
data
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %% [markdown]
# # Analyse The Data

# %%
data.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.shape
# Out:
# (366, 22)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
data.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
data.dtypes
# Out:
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
y1=data['MinTemp']
y2=data['MaxTemp']
x=np.arange(len(y1))
fig=plt.figure()
ax=plt.axes()
ax.plot(x,y1,'r')
ax.plot(x,y2,'b')

# %%
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
data['WindGustSpeed'].unique()
# Out:
# array([30., 39., 85., 54., 50., 44., 43., 41., 48., 31., 46., 52., 33.,
#        59., 26., 28., 35., 22., 76., 65., 57., 69., 61., 24., 83., 63.,
#        17., 20., nan, 15., 13., 70., 78., 67., 98., 80.])

# %%
data.nunique()
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
data.count(axis=0)
# Out:
# MinTemp          366
# MaxTemp          366
# Rainfall         366
# Evaporation      366
# Sunshine         363
# WindGustDir      363
# WindGustSpeed    364
# WindDir9am       335
# WindDir3pm       365
# WindSpeed9am     359
# WindSpeed3pm     366
# Humidity9am      366
# Humidity3pm      366
# Pressure9am      366
# Pressure3pm      366
# Cloud9am         366
# Cloud3pm         366
# Temp9am          366
# Temp3pm          366
# RainToday        366
# RISK_MM          366
# RainTomorrow     366
# dtype: int64

# %%
data['RainToday'].value_counts()
# Out:
# No     300
# Yes     66
# Name: RainToday, dtype: int64

# %%
data['Humidity9am'].value_counts()
# Out:
# 69    19
# 74    17
# 70    16
# 76    14
# 60    12
# 82    12
# 80    12
# 68    11
# 72    11
# 73    11
# 78    11
# 81    11
# 71    10
# 92    10
# 66    10
# 67     9
# 65     9
# 63     9
# 99     9
# 77     8
# 84     7
# 62     6
# 59     6
# 75     6
# 54     6
# 88     5
# 44     5
# 79     5
# 58     5
# 64     5
# 56     5
# 93     4
# 83     4
# 90     4
# 89     4
# 95     4
# 61     4
# 57     4
# 91     4
# 94     3
# 86     3
# 97     3
# 85     3
# 45     3
# 43     3
# 47     3
# 50     3
# 53     3
# 87     2
# 52     2
# 55     2
# 42     1
# 46     1
# 48     1
# 49     1
# 51     1
# 41     1
# 38     1
# 96     1
# 36     1
# Name: Humidity9am, dtype: int64

# %%
#Find all  unique "windspeed " values in the data

# %%
#ans

# %%
data.nunique()
# Out:
# MinTemp          180
# MaxTemp          187
# Rainfall          47
# Evaporation       55
# Sunshine         114
# WindGustDir       16
# WindGustSpeed     35
# WindDir9am        16
# WindDir3pm        16
# WindSpeed9am      22
# WindSpeed3pm      26
# Humidity9am       60
# Humidity3pm       74
# Pressure9am      190
# Pressure3pm      193
# Cloud9am           9
# Cloud3pm           9
# Temp9am          178
# Temp3pm          200
# RainToday          2
# RISK_MM           47
# RainTomorrow       2
# dtype: int64

# %%
data['WindSpeed9am'].nunique()
# Out:
# 22

# %%
data['WindSpeed9am'].unique()
# Out:
# array([ 6.,  4., 30., 20., 19., 11.,  7.,  2., 13.,  9., 15., 22., 41.,
#        24., 17., nan,  0., 26., 33., 31., 28., 39., 35.])

# %%
#No of times Rain Today is Yes?

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
#
# [2 rows x 22 columns]

# %%
#value_counts()
data['RainToday'].value_counts()
# Out:
# No     300
# Yes     66
# Name: RainToday, dtype: int64

# %%
#filtring
filt=(data['RainToday']=='Yes')
data[filt]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 9        8.4     22.8      16.2          5.4       7.7           E
# ..       ...      ...       ...          ...       ...         ...
# 327      7.8     16.2      17.4          6.4       7.9          NW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 339     10.3     21.3       3.0          4.2       6.7         NNW
# 341      0.3     16.0       8.2          5.4      11.8          NW
# 348     11.9     21.1      13.2          6.6       NaN          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1             39.0          E          W           4.0  ...           36
# ...

# %%
#group by 
data.groupby('RainToday').get_group('Yes')
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# 9        8.4     22.8      16.2          5.4       7.7           E
# ..       ...      ...       ...          ...       ...         ...
# 327      7.8     16.2      17.4          6.4       7.9          NW
# 338     14.4     20.7       7.6          9.4       4.9         NNW
# 339     10.3     21.3       3.0          4.2       6.7         NNW
# 341      0.3     16.0       8.2          5.4      11.8          NW
# 348     11.9     21.1      13.2          6.6       NaN          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 1             39.0          E          W           4.0  ...           36
# ...

# %%
#Wind Speed is 46

# %%
data['WindGustSpeed'].value_counts()
# Out:
# 41.0    32
# 39.0    31
# 31.0    30
# 35.0    24
# 30.0    23
# 46.0    23
# 33.0    19
# 48.0    18
# 43.0    18
# 50.0    16
# 44.0    15
# 28.0    15
# 22.0    11
# 52.0    10
# 26.0    10
# 59.0     9
# 20.0     9
# 17.0     7
# 57.0     6
# 65.0     6
# 24.0     6
# 70.0     4
# 54.0     4
# 61.0     2
# 13.0     2
# 76.0     2
# 78.0     2
# 15.0     2
# 63.0     2
# 85.0     1
# 80.0     1
# 69.0     1
# 83.0     1
# 98.0     1
# 67.0     1
# Name: WindGustSpeed, dtype: int64

# %%
filt=(data['WindGustSpeed']==46)

# %%
data[filt]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 15      12.4     32.1       0.0          8.4      11.1           E
# 64      16.7     25.3       0.0          6.2      12.5         ESE
# 68      16.5     30.3       0.0         10.0       8.1           E
# 77      15.2     25.1       4.8          6.4      11.6           E
# 87      13.2     31.3       0.0          6.6      11.6         WSW
# 89      17.9     33.9       0.0         10.4      11.8         ENE
# 108     12.1     24.1       0.0          7.4      10.2         ENE
# 114     12.7     25.1       0.0          7.8      12.4          NW
# 125     12.0     27.6       0.0          6.0      11.0           E
# 131     13.9     34.7       0.0          6.4       8.5         SSW
# 140     11.5     29.3       0.0          5.2       8.0          NW
# 146     12.6     20.2      19.8          2.6       9.1           W
# 223     10.2     15.0       4.8          0.2       0.5          NW
# ...

# %%
#Find NULL Values

# %%
data.isnull()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0      False    False     False        False     False        False
# 1      False    False     False        False     False        False
# 2      False    False     False        False     False        False
# 3      False    False     False        False     False        False
# 4      False    False     False        False     False        False
# ..       ...      ...       ...          ...       ...          ...
# 361    False    False     False        False     False        False
# 362    False    False     False        False     False        False
# 363    False    False     False        False     False        False
# 364    False    False     False        False     False        False
# 365    False    False     False        False     False        False
#
#      WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %%
data.isnull().sum()
# Out:
# MinTemp           0
# MaxTemp           0
# Rainfall          0
# Evaporation       0
# Sunshine          3
# WindGustDir       3
# WindGustSpeed     2
# WindDir9am       31
# WindDir3pm        1
# WindSpeed9am      7
# WindSpeed3pm      0
# Humidity9am       0
# Humidity3pm       0
# Pressure9am       0
# Pressure3pm       0
# Cloud9am          0
# Cloud3pm          0
# Temp9am           0
# Temp3pm           0
# RainToday         0
# RISK_MM           0
# RainTomorrow      0
# dtype: int64

# %%
#Rename WindGustSpeed as WindSpeed

# %%
data.rename(columns={'WindGustSpeed':'WindSpeed'},inplace=True)

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  WindSpeed  \
# 0      8.0     24.3       0.0          3.4       6.3          NW       30.0
# 1     14.0     26.9       3.6          4.4       9.7         ENE       39.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  Pressure9am  \
# 0         SW         NW           6.0  ...           29       1019.7
# 1          E          W           4.0  ...           36       1012.4
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1015.0         7         7     14.4     23.6         No      3.6
# 1       1008.4         5         3     17.5     25.7        Yes      3.6
#
#   RainTomorrow
# 0          Yes
# 1          Yes
#
# [2 rows x 22 columns]

# %%
#Mean MaxTemp

# %%
data.head(2)
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  WindSpeed  \
# 0      8.0     24.3       0.0          3.4       6.3          NW       30.0
# 1     14.0     26.9       3.6          4.4       9.7         ENE       39.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  Pressure9am  \
# 0         SW         NW           6.0  ...           29       1019.7
# 1          E          W           4.0  ...           36       1012.4
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1015.0         7         7     14.4     23.6         No      3.6
# 1       1008.4         5         3     17.5     25.7        Yes      3.6
#
#   RainTomorrow
# 0          Yes
# 1          Yes
#
# [2 rows x 22 columns]

# %%
data.MaxTemp.mean()
# Out:
# 20.550273224043714

# %%
#standard deviation Pressure at 9am

# %%
data.Pressure9am.std()
# Out:
# 6.6862115828948605

# %%
#Variance of Humidity

# %%
data.Humidity3pm.var()
# Out:
# 283.95442772662625

# %%
#Find data Min Temp>15 Max temp<25

# %%
filt=(data['MinTemp']>15) & (data['MaxTemp']<25)

# %%
data[filt]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  WindSpeed  \
# 21      16.4     19.4       0.4          9.2       0.0           E       26.0
# 28      15.1     24.3       0.0          7.0       0.4          SE       39.0
# 30      15.1     20.4      22.6          2.4       0.2         SSE       41.0
# 32      16.6     24.2       0.2          6.6       4.7          NW       50.0
# 45      15.5     21.1       5.4          6.4       0.9           S       31.0
# 51      19.9     22.0      11.0          4.4       5.9         NNW       76.0
# 63      15.9     23.4       0.0         12.6       2.2         ESE       50.0
# 74      16.0     22.8       0.0         12.4       6.0           E       50.0
# 78      15.1     20.4       0.0          9.6       0.1         ESE       39.0
# 79      15.3     19.6      18.8          5.0       0.0          NE       33.0
# 80      17.2     24.7      12.2          1.4       8.1          NW       50.0
# ...

# %%
#What is the mean value of each column against each WindGustSpedd

# %%
data.groupby('WindGustDir').mean()
# Out:
#                MinTemp    MaxTemp  Rainfall  Evaporation   Sunshine  \
# WindGustDir
# E             9.981081  24.086486  0.718919     5.567568   8.600000
# ENE          11.213333  23.333333  1.720000     5.860000   7.910000
# ESE           9.169565  20.821739  2.000000     4.852174   5.978261
# N             2.919048  18.538095  0.400000     4.047619   9.209524
# NE           10.750000  25.893750  1.425000     6.075000   8.981250
# NNE          10.275000  23.737500  0.575000     3.575000   7.971429
# NNW           6.022727  20.459091  1.463636     4.368182   8.018182
# NW            6.131507  19.478082  2.084932     4.084932   8.108333
# S             5.131818  17.013636  1.372727     3.563636   7.759091
# SE            7.183333  18.491667  0.100000     4.250000   5.808333
# SSE           7.600000  18.750000  2.616667     4.416667   7.100000
# SSW           7.640000  23.400000  0.000000     5.000000   6.950000
# SW           14.566667  27.000000  0.000000     6.933333   7.500000
# ...

# %%
#What is the minimum && Maximum value of each column against each WindGustSpedd

# %%
data.groupby('RainToday')
